# %%
from Tumor_Classifier_Utils import *

# %%
# loading in data
train, train_y, val, val_y, test, test_y, N, num_classes = load_data(64)


print(train.shape)
print(val.shape)
print(test.shape)
print(train_y.shape)
print(val_y.shape)
print(test_y.shape)
# Out:
# (2450, 64, 64, 1)
# (350, 64, 64, 1)
# (283, 64, 64, 1)
# (2450, 1)
# (350, 1)
# (283, 1)

# %%
train_LDA = np.reshape(train[:,:,:,:], (2450, -1))
val_LDA = np.reshape(val[:,:,:,:], (350, -1))
test_LDA = np.reshape(test[:,:,:,:], (283, -1))

print(train_LDA.shape)
# Out:
# (2450, 4096)

# %%
lda = discriminant_analysis.LinearDiscriminantAnalysis()
lda.fit(np.array(train_LDA), np.array(train_y))

transformed_train_LDA = lda.transform(train_LDA)
transformed_val_LDA = lda.transform(val_LDA)
transformed_test_LDA = lda.transform(test_LDA)
# Out:
# c:\Users\61424\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py:1107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
new_train = np.reshape(train[:,:], (2450, N, N, 1))
new_val = np.reshape(val[:,:], (350, N, N, 1))
new_test = np.reshape(test[:,:], (283, N, N, 1))

# %%
def GetSiameseData(imgs, labels, batch_size):

    image_a = np.zeros((batch_size, np.shape(imgs)[1], np.shape(imgs)[2], np.shape(imgs)[3]));
    image_b = np.zeros((batch_size, np.shape(imgs)[1], np.shape(imgs)[2], np.shape(imgs)[3]));
    label = np.zeros(batch_size);
    
    for i in range(batch_size):
        
        if (i % 2 == 0):
            idx1 = random.randint(0, len(imgs) - 1)
            idx2 = random.randint(0, len(imgs) - 1)
            l = 1
            while (labels[idx1] != labels[idx2]):
                idx2 = random.randint(0, len(imgs) - 1)            
                
        else:
            idx1 = random.randint(0, len(imgs) - 1)
            idx2 = random.randint(0, len(imgs) - 1)
            l = 0
            while (labels[idx1] == labels[idx2]):
                idx2 = random.randint(0, len(imgs) - 1)

        image_a[i, :, :, :] = imgs[idx1,:,:,:]
        image_b[i, :, :, :] = imgs[idx2,:,:,:]
        label[i] = l

    return [image_a, image_b], label

def PairGenerator(imgs, labels, batch_size):
    while True:
        [image_a, image_b], label = GetSiameseData(imgs, labels, batch_size)
        yield [image_a, image_b], label

# %%
test_gen = PairGenerator(new_train, train_y, 10)
x, y = next(test_gen)

fig = plt.figure(figsize=[25, 6])
for i in range(10):
    ax = fig.add_subplot(2, 10, i*2 + 1)
    ax.imshow(x[0][i,:,:,0])
    ax.set_title('Pair ' + str(i) +'; Label: ' + str(y[i]))
    ax.axis('off')
    
    ax = fig.add_subplot(2, 10, i*2 + 2)
    ax.imshow(x[1][i,:,:,0])    
    ax.set_title('Pair ' + str(i) +'; Label: ' + str(y[i]))  
    ax.axis('off')

# %%
def conv_block(inputs, filters, spatial_dropout = 0.0, max_pool = True):
    
    x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if (spatial_dropout > 0.0):
        x = layers.SpatialDropout2D(spatial_dropout)(x)
    if (max_pool == True):
        x = layers.MaxPool2D(pool_size=(2, 2))(x)
    
    return x

def fc_block(inputs, size, dropout):
    x = layers.Dense(size, activation=None)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if (dropout > 0.0):
        x = layers.Dropout(dropout)(x)
    
    return x

def vgg_net(inputs, filters, fc, spatial_dropout = 0.0, dropout = 0.0):
    
    x = inputs
    for idx,i in enumerate(filters):
        x = conv_block(x, i, spatial_dropout, not (idx==len(filters) - 1))
    
    x = layers.Flatten()(x)
    
    for i in fc:
        x = fc_block(x, i, dropout)
        
    return x

# %%
embedding_size = 32
dummy_input = keras.Input((N, N, 1))
base_network = vgg_net(dummy_input, [8, 16, 32], [256], 0.2, 0)
embedding_layer = layers.Dense(embedding_size, activation=None)(base_network)
base_network = keras.Model(dummy_input, embedding_layer, name='SiameseBranch')
base_network.summary()
# Out:
# Model: "SiameseBranch"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 8)         80
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 8)         584
#
#  batch_normalization (BatchN  (None, 64, 64, 8)        32
#  ormalization)
#
#  activation (Activation)     (None, 64, 64, 8)         0
#
#  spatial_dropout2d (SpatialD  (None, 64, 64, 8)        0
#  ropout2D)
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 8)        0
#  )
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_1 (Batc  (None, 32, 32, 16)       64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 16)        0
#
#  spatial_dropout2d_1 (Spatia  (None, 32, 32, 16)       0
#  lDropout2D)
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 32)        0
#
#  spatial_dropout2d_2 (Spatia  (None, 16, 16, 32)       0
#  lDropout2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dense_1 (Dense)             (None, 32)                8224
#
# =================================================================
# Total params: 2,124,920
# Trainable params: 2,124,296
# Non-trainable params: 624
# _________________________________________________________________

# %%
input_a = keras.Input((N, N, 1), name='InputA')
input_b = keras.Input((N, N, 1), name='InputB')

embedding_a = base_network(input_a)
embedding_b = base_network(input_b)

# %%
combined = layers.concatenate([embedding_a, embedding_b])
combined = layers.Dense(128, activation='relu')(combined)
output = layers.Dense(1, activation='sigmoid')(combined)

siamese_network = keras.Model([input_a, input_b], output, name='SiameseNetwork')
siamese_network.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  InputA (InputLayer)            [(None, 64, 64, 1)]  0           []
#
#  InputB (InputLayer)            [(None, 64, 64, 1)]  0           []
#
#  SiameseBranch (Functional)     (None, 32)           2124920     ['InputA[0][0]',
#                                                                   'InputB[0][0]']
#
#  concatenate (Concatenate)      (None, 64)           0           ['SiameseBranch[0][0]',
#                                                                   'SiameseBranch[1][0]']
#
#  dense_2 (Dense)                (None, 128)          8320        ['concatenate[0][0]']
#
#  dense_3 (Dense)                (None, 1)            129         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 2,133,369
# Trainable params: 2,132,745
# Non-trainable params: 624
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(siamese_network, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
siamese_network.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
batch_size = 128
training_gen = PairGenerator(new_train, train_y, batch_size)

siamese_test_x, siamese_test_y = GetSiameseData(new_test, test_y, 128)

classWeights = class_weights()
history = siamese_network.fit(training_gen, steps_per_epoch = 2000 // batch_size, epochs=100, validation_data = (siamese_test_x, siamese_test_y), class_weight=classWeights)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 5s 52ms/step - loss: 1.0761 - accuracy: 0.5047 - val_loss: 0.7077 - val_accuracy: 0.5000
# Epoch 2/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.9986 - accuracy: 0.5078 - val_loss: 0.8232 - val_accuracy: 0.5000
# Epoch 3/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.9835 - accuracy: 0.4990 - val_loss: 0.7651 - val_accuracy: 0.5000
# Epoch 4/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.9519 - accuracy: 0.5135 - val_loss: 0.7131 - val_accuracy: 0.5000
# Epoch 5/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.9479 - accuracy: 0.5312 - val_loss: 0.7524 - val_accuracy: 0.5000
# Epoch 6/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.9148 - accuracy: 0.5464 - val_loss: 0.7266 - val_accuracy: 0.5000
# Epoch 7/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.8971 - accuracy: 0.5620 - val_loss: 0.7056 - val_accuracy: 0.5000
# Epoch 8/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.8508 - accuracy: 0.6104 - val_loss: 0.7301 - val_accuracy: 0.5000
# Epoch 9/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.8550 - accuracy: 0.6073 - val_loss: 0.7335 - val_accuracy: 0.5000
# Epoch 10/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.8236 - accuracy: 0.6229 - val_loss: 0.7564 - val_accuracy: 0.5000
# Epoch 11/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.7835 - accuracy: 0.6385 - val_loss: 0.6959 - val_accuracy: 0.5312
# Epoch 12/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.7879 - accuracy: 0.6396 - val_loss: 0.6908 - val_accuracy: 0.5547
# Epoch 13/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.7402 - accuracy: 0.6578 - val_loss: 0.7220 - val_accuracy: 0.4844
# Epoch 14/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.7621 - accuracy: 0.6630 - val_loss: 0.7209 - val_accuracy: 0.5391
# Epoch 15/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6790 - accuracy: 0.7063 - val_loss: 0.6648 - val_accuracy: 0.6172
# Epoch 16/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6916 - accuracy: 0.6969 - val_loss: 0.7023 - val_accuracy: 0.6016
# Epoch 17/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6818 - accuracy: 0.7224 - val_loss: 0.7474 - val_accuracy: 0.5859
# Epoch 18/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6367 - accuracy: 0.7318 - val_loss: 0.6748 - val_accuracy: 0.6562
# Epoch 19/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6472 - accuracy: 0.7104 - val_loss: 0.6761 - val_accuracy: 0.6250
# Epoch 20/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6219 - accuracy: 0.7297 - val_loss: 0.6948 - val_accuracy: 0.6484
# Epoch 21/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6081 - accuracy: 0.7229 - val_loss: 0.6876 - val_accuracy: 0.6328
# Epoch 22/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5678 - accuracy: 0.7635 - val_loss: 0.6272 - val_accuracy: 0.6250
# Epoch 23/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5716 - accuracy: 0.7573 - val_loss: 0.6186 - val_accuracy: 0.6328
# Epoch 24/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5599 - accuracy: 0.7594 - val_loss: 0.6716 - val_accuracy: 0.6016
# Epoch 25/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5858 - accuracy: 0.7630 - val_loss: 0.5915 - val_accuracy: 0.6406
# Epoch 26/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5370 - accuracy: 0.7599 - val_loss: 0.5442 - val_accuracy: 0.6797
# Epoch 27/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5309 - accuracy: 0.7812 - val_loss: 0.6062 - val_accuracy: 0.6797
# Epoch 28/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5229 - accuracy: 0.7771 - val_loss: 0.6226 - val_accuracy: 0.6719
# Epoch 29/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5154 - accuracy: 0.7740 - val_loss: 0.7025 - val_accuracy: 0.6328
# Epoch 30/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5071 - accuracy: 0.7818 - val_loss: 0.5456 - val_accuracy: 0.7266
# Epoch 31/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.5004 - accuracy: 0.7922 - val_loss: 0.6008 - val_accuracy: 0.6406
# Epoch 32/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4822 - accuracy: 0.7859 - val_loss: 0.5560 - val_accuracy: 0.6797
# Epoch 33/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4484 - accuracy: 0.8313 - val_loss: 0.5610 - val_accuracy: 0.6641
# Epoch 34/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4706 - accuracy: 0.8104 - val_loss: 0.5850 - val_accuracy: 0.6641
# Epoch 35/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4472 - accuracy: 0.8281 - val_loss: 0.5143 - val_accuracy: 0.7109
# Epoch 36/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4391 - accuracy: 0.8375 - val_loss: 0.5325 - val_accuracy: 0.6953
# Epoch 37/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4226 - accuracy: 0.8333 - val_loss: 0.6719 - val_accuracy: 0.6328
# Epoch 38/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4185 - accuracy: 0.8370 - val_loss: 0.5333 - val_accuracy: 0.7031
# Epoch 39/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4191 - accuracy: 0.8380 - val_loss: 0.5142 - val_accuracy: 0.7188
# Epoch 40/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4209 - accuracy: 0.8427 - val_loss: 0.5923 - val_accuracy: 0.7266
# Epoch 41/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4126 - accuracy: 0.8469 - val_loss: 0.4629 - val_accuracy: 0.7891
# Epoch 42/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3938 - accuracy: 0.8672 - val_loss: 0.4839 - val_accuracy: 0.7812
# Epoch 43/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3591 - accuracy: 0.8776 - val_loss: 0.4531 - val_accuracy: 0.7734
# Epoch 44/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.3307 - accuracy: 0.8943 - val_loss: 0.6734 - val_accuracy: 0.6562
# Epoch 45/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.3513 - accuracy: 0.8839 - val_loss: 0.5189 - val_accuracy: 0.7500
# Epoch 46/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.3148 - accuracy: 0.9104 - val_loss: 0.5217 - val_accuracy: 0.7734
# Epoch 47/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.3127 - accuracy: 0.8979 - val_loss: 0.5955 - val_accuracy: 0.7188
# Epoch 48/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.2803 - accuracy: 0.9146 - val_loss: 0.8271 - val_accuracy: 0.6562
# Epoch 49/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.3016 - accuracy: 0.9016 - val_loss: 0.6120 - val_accuracy: 0.7266
# Epoch 50/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.2595 - accuracy: 0.9177 - val_loss: 0.6067 - val_accuracy: 0.7266
# Epoch 51/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2563 - accuracy: 0.9193 - val_loss: 0.8035 - val_accuracy: 0.7109
# Epoch 52/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2448 - accuracy: 0.9219 - val_loss: 0.7426 - val_accuracy: 0.7188
# Epoch 53/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2299 - accuracy: 0.9349 - val_loss: 0.6371 - val_accuracy: 0.7422
# Epoch 54/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1905 - accuracy: 0.9438 - val_loss: 0.5433 - val_accuracy: 0.7656
# Epoch 55/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1886 - accuracy: 0.9406 - val_loss: 0.6496 - val_accuracy: 0.7266
# Epoch 56/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1629 - accuracy: 0.9516 - val_loss: 0.7729 - val_accuracy: 0.7031
# Epoch 57/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1626 - accuracy: 0.9609 - val_loss: 0.5204 - val_accuracy: 0.7891
# Epoch 58/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1418 - accuracy: 0.9557 - val_loss: 0.5183 - val_accuracy: 0.7734
# Epoch 59/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1244 - accuracy: 0.9677 - val_loss: 0.5430 - val_accuracy: 0.8359
# Epoch 60/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1294 - accuracy: 0.9688 - val_loss: 0.6517 - val_accuracy: 0.7812
# Epoch 61/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0972 - accuracy: 0.9760 - val_loss: 0.5370 - val_accuracy: 0.8203
# Epoch 62/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1237 - accuracy: 0.9635 - val_loss: 0.4551 - val_accuracy: 0.8281
# Epoch 63/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0930 - accuracy: 0.9729 - val_loss: 0.4745 - val_accuracy: 0.8203
# Epoch 64/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0965 - accuracy: 0.9724 - val_loss: 0.5228 - val_accuracy: 0.8203
# Epoch 65/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0669 - accuracy: 0.9839 - val_loss: 0.5992 - val_accuracy: 0.7656
# Epoch 66/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0824 - accuracy: 0.9786 - val_loss: 0.6429 - val_accuracy: 0.7812
# Epoch 67/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0790 - accuracy: 0.9802 - val_loss: 0.8485 - val_accuracy: 0.7500
# Epoch 68/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0621 - accuracy: 0.9854 - val_loss: 0.6371 - val_accuracy: 0.8047
# Epoch 69/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0689 - accuracy: 0.9802 - val_loss: 0.6323 - val_accuracy: 0.7734
# Epoch 70/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0567 - accuracy: 0.9865 - val_loss: 0.6033 - val_accuracy: 0.7734
# Epoch 71/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0592 - accuracy: 0.9859 - val_loss: 0.7188 - val_accuracy: 0.7656
# Epoch 72/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0730 - accuracy: 0.9823 - val_loss: 0.9888 - val_accuracy: 0.7031
# Epoch 73/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0620 - accuracy: 0.9833 - val_loss: 0.7401 - val_accuracy: 0.8047
# Epoch 74/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0581 - accuracy: 0.9844 - val_loss: 0.9656 - val_accuracy: 0.7656
# Epoch 75/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0479 - accuracy: 0.9880 - val_loss: 0.6775 - val_accuracy: 0.7969
# Epoch 76/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0580 - accuracy: 0.9828 - val_loss: 0.4369 - val_accuracy: 0.8594
# Epoch 77/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0585 - accuracy: 0.9854 - val_loss: 0.4767 - val_accuracy: 0.8516
# Epoch 78/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0536 - accuracy: 0.9854 - val_loss: 0.5904 - val_accuracy: 0.8203
# Epoch 79/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0456 - accuracy: 0.9870 - val_loss: 0.5727 - val_accuracy: 0.8281
# Epoch 80/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0636 - accuracy: 0.9818 - val_loss: 0.6356 - val_accuracy: 0.8281
# Epoch 81/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0622 - accuracy: 0.9865 - val_loss: 0.5261 - val_accuracy: 0.8672
# Epoch 82/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0432 - accuracy: 0.9885 - val_loss: 0.5924 - val_accuracy: 0.8594
# Epoch 83/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0478 - accuracy: 0.9896 - val_loss: 0.5842 - val_accuracy: 0.8438
# Epoch 84/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0632 - accuracy: 0.9833 - val_loss: 0.5888 - val_accuracy: 0.8516
# Epoch 85/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0282 - accuracy: 0.9948 - val_loss: 0.7841 - val_accuracy: 0.7812
# Epoch 86/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0416 - accuracy: 0.9901 - val_loss: 0.6207 - val_accuracy: 0.8281
# Epoch 87/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0390 - accuracy: 0.9917 - val_loss: 0.5844 - val_accuracy: 0.8438
# Epoch 88/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0543 - accuracy: 0.9865 - val_loss: 0.6156 - val_accuracy: 0.7500
# Epoch 89/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0322 - accuracy: 0.9917 - val_loss: 0.7942 - val_accuracy: 0.7656
# Epoch 90/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0413 - accuracy: 0.9880 - val_loss: 0.7937 - val_accuracy: 0.7500
# Epoch 91/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0333 - accuracy: 0.9911 - val_loss: 0.6014 - val_accuracy: 0.8203
# Epoch 92/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0404 - accuracy: 0.9927 - val_loss: 0.6622 - val_accuracy: 0.8125
# Epoch 93/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0328 - accuracy: 0.9906 - val_loss: 0.5784 - val_accuracy: 0.8203
# Epoch 94/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0432 - accuracy: 0.9906 - val_loss: 0.5236 - val_accuracy: 0.8281
# Epoch 95/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0298 - accuracy: 0.9948 - val_loss: 0.4924 - val_accuracy: 0.8281
# Epoch 96/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0274 - accuracy: 0.9932 - val_loss: 0.6031 - val_accuracy: 0.8203
# Epoch 97/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0318 - accuracy: 0.9911 - val_loss: 0.7178 - val_accuracy: 0.8281
# Epoch 98/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0322 - accuracy: 0.9937 - val_loss: 0.6189 - val_accuracy: 0.8125
# Epoch 99/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0257 - accuracy: 0.9937 - val_loss: 0.8055 - val_accuracy: 0.7969
# Epoch 100/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0280 - accuracy: 0.9932 - val_loss: 0.6038 - val_accuracy: 0.8125

# %%
plot_loss(history)

# %%
x, y = GetSiameseData(new_test, test_y, 10)
res = siamese_network.predict(x)

fig = plt.figure(figsize=[25, 6])
for i in range(10):
    ax = fig.add_subplot(2, 10, i*2 + 1)
    ax.imshow(x[0][i,:,:,0])
    ax.set_title('Pair ' + str(i) +'; Label: ' + str(y[i]))
    ax.axis('off')
    
    ax = fig.add_subplot(2, 10, i*2 + 2)
    ax.imshow(x[1][i,:,:,0])    
    ax.set_title('Predicted: ' + str(res[i]))
    ax.axis('off')

# %%
for i in range(10):
    x[0][i,:] = x[0][0,:]

res = siamese_network.predict(x)

fig = plt.figure(figsize=[25, 6])
for i in range(10):
    ax = fig.add_subplot(2, 10, i*2 + 1)
    ax.imshow(x[0][i,:,:,0])
    ax.set_title('Pair ' + str(i))
    ax.axis('off')
    
    ax = fig.add_subplot(2, 10, i*2 + 2)
    ax.imshow(x[1][i,:,:,0])    
    ax.set_title('Predicted: ' + str(res[i]))
    ax.axis('off')

# %%
embeddings = base_network.predict(test)
tsne_embeddings = TSNE(random_state=4).fit_transform(embeddings)
fig = plt.figure(figsize=[12, 12])
ax = fig.add_subplot(1, 1, 1)
labels = ['No tumor', 'Glioma Tumor', 'Meningioma Tumor', 'Pituitary Tumor']
scatter = ax.scatter(tsne_embeddings[:,0], tsne_embeddings[:,1], c = test_y.flatten(), label=labels);
handles, _ = scatter.legend_elements(prop='colors')
plt.legend(handles, labels)
plt.show()
# Out:
# c:\Users\61424\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\61424\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
