# %%
from Tumor_Classifier_Utils import *

# %%
# loading in data
train, train_y, val, val_y, test, test_y, N, num_classes = load_data(64)


print(train.shape)
print(val.shape)
print(test.shape)
print(train_y.shape)
print(val_y.shape)
print(test_y.shape)
# Out:
# (2450, 64, 64, 1)
# (350, 64, 64, 1)
# (283, 64, 64, 1)
# (2450, 1)
# (350, 1)
# (283, 1)

# %%
train_LDA = np.reshape(train[:,:,:,:], (2450, -1))
val_LDA = np.reshape(val[:,:,:,:], (350, -1))
test_LDA = np.reshape(test[:,:,:,:], (283, -1))

print(train_LDA.shape)
# Out:
# (2450, 4096)

# %%
lda = discriminant_analysis.LinearDiscriminantAnalysis()
lda.fit(np.array(train_LDA), np.array(train_y))

transformed_train_LDA = lda.transform(train_LDA)
transformed_val_LDA = lda.transform(val_LDA)
transformed_test_LDA = lda.transform(test_LDA)
# Out:
# c:\Users\61424\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py:1107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
new_train = np.reshape(train[:,:], (2450, N, N, 1))
new_val = np.reshape(val[:,:], (350, N, N, 1))
new_test = np.reshape(test[:,:], (283, N, N, 1))

# %%
def GetSiameseData(imgs, labels, batch_size):

    image_a = np.zeros((batch_size, np.shape(imgs)[1], np.shape(imgs)[2], np.shape(imgs)[3]));
    image_b = np.zeros((batch_size, np.shape(imgs)[1], np.shape(imgs)[2], np.shape(imgs)[3]));
    label = np.zeros(batch_size);
    
    for i in range(batch_size):
        
        if (i % 2 == 0):
            idx1 = random.randint(0, len(imgs) - 1)
            idx2 = random.randint(0, len(imgs) - 1)
            l = 1
            while (labels[idx1] != labels[idx2]):
                idx2 = random.randint(0, len(imgs) - 1)            
                
        else:
            idx1 = random.randint(0, len(imgs) - 1)
            idx2 = random.randint(0, len(imgs) - 1)
            l = 0
            while (labels[idx1] == labels[idx2]):
                idx2 = random.randint(0, len(imgs) - 1)

        image_a[i, :, :, :] = imgs[idx1,:,:,:]
        image_b[i, :, :, :] = imgs[idx2,:,:,:]
        label[i] = l

    return [image_a, image_b], label

def PairGenerator(imgs, labels, batch_size):
    while True:
        [image_a, image_b], label = GetSiameseData(imgs, labels, batch_size)
        yield [image_a, image_b], label

# %%
test_gen = PairGenerator(new_train, train_y, 10)
x, y = next(test_gen)

fig = plt.figure(figsize=[25, 6])
for i in range(10):
    ax = fig.add_subplot(2, 10, i*2 + 1)
    ax.imshow(x[0][i,:,:,0])
    ax.set_title('Pair ' + str(i) +'; Label: ' + str(y[i]))
    ax.axis('off')
    
    ax = fig.add_subplot(2, 10, i*2 + 2)
    ax.imshow(x[1][i,:,:,0])    
    ax.set_title('Pair ' + str(i) +'; Label: ' + str(y[i]))  
    ax.axis('off')

# %%
def conv_block(inputs, filters, spatial_dropout = 0.0, max_pool = True):
    
    x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if (spatial_dropout > 0.0):
        x = layers.SpatialDropout2D(spatial_dropout)(x)
    if (max_pool == True):
        x = layers.MaxPool2D(pool_size=(2, 2))(x)
    
    return x

def fc_block(inputs, size, dropout):
    x = layers.Dense(size, activation=None)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if (dropout > 0.0):
        x = layers.Dropout(dropout)(x)
    
    return x

def vgg_net(inputs, filters, fc, spatial_dropout = 0.0, dropout = 0.0):
    
    x = inputs
    for idx,i in enumerate(filters):
        x = conv_block(x, i, spatial_dropout, not (idx==len(filters) - 1))
    
    x = layers.Flatten()(x)
    
    for i in fc:
        x = fc_block(x, i, dropout)
        
    return x

# %%
embedding_size = 32
dummy_input = keras.Input((N, N, 1))
base_network = vgg_net(dummy_input, [8, 16, 32], [256], 0.2, 0)
embedding_layer = layers.Dense(embedding_size, activation=None)(base_network)
base_network = keras.Model(dummy_input, embedding_layer, name='SiameseBranch')
base_network.summary()
# Out:
# Model: "SiameseBranch"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 8)         80
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 8)         584
#
#  batch_normalization (BatchN  (None, 64, 64, 8)        32
#  ormalization)
#
#  activation (Activation)     (None, 64, 64, 8)         0
#
#  spatial_dropout2d (SpatialD  (None, 64, 64, 8)        0
#  ropout2D)
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 8)        0
#  )
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_1 (Batc  (None, 32, 32, 16)       64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 16)        0
#
#  spatial_dropout2d_1 (Spatia  (None, 32, 32, 16)       0
#  lDropout2D)
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 32)        0
#
#  spatial_dropout2d_2 (Spatia  (None, 16, 16, 32)       0
#  lDropout2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dense_1 (Dense)             (None, 32)                8224
#
# =================================================================
# Total params: 2,124,920
# Trainable params: 2,124,296
# Non-trainable params: 624
# _________________________________________________________________

# %%
input_a = keras.Input((N, N, 1), name='InputA')
input_b = keras.Input((N, N, 1), name='InputB')

embedding_a = base_network(input_a)
embedding_b = base_network(input_b)

# %%
combined = layers.concatenate([embedding_a, embedding_b])
combined = layers.Dense(128, activation='relu')(combined)
output = layers.Dense(1, activation='sigmoid')(combined)

siamese_network = keras.Model([input_a, input_b], output, name='SiameseNetwork')
siamese_network.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  InputA (InputLayer)            [(None, 64, 64, 1)]  0           []
#
#  InputB (InputLayer)            [(None, 64, 64, 1)]  0           []
#
#  SiameseBranch (Functional)     (None, 32)           2124920     ['InputA[0][0]',
#                                                                   'InputB[0][0]']
#
#  concatenate (Concatenate)      (None, 64)           0           ['SiameseBranch[0][0]',
#                                                                   'SiameseBranch[1][0]']
#
#  dense_2 (Dense)                (None, 128)          8320        ['concatenate[0][0]']
#
#  dense_3 (Dense)                (None, 1)            129         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 2,133,369
# Trainable params: 2,132,745
# Non-trainable params: 624
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(siamese_network, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
siamese_network.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
batch_size = 128
training_gen = PairGenerator(new_train, train_y, batch_size)

siamese_test_x, siamese_test_y = GetSiameseData(new_test, test_y, 128)

classWeights = class_weights()
history = siamese_network.fit(training_gen, steps_per_epoch = 2000 // batch_size, epochs=100, validation_data = (siamese_test_x, siamese_test_y), class_weight=classWeights)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 4s 55ms/step - loss: 1.0424 - accuracy: 0.4948 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 2/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.9742 - accuracy: 0.5005 - val_loss: 0.6966 - val_accuracy: 0.5000
# Epoch 3/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.9607 - accuracy: 0.5198 - val_loss: 0.7076 - val_accuracy: 0.5000
# Epoch 4/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.9417 - accuracy: 0.5276 - val_loss: 0.6985 - val_accuracy: 0.5000
# Epoch 5/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.9110 - accuracy: 0.5625 - val_loss: 0.7320 - val_accuracy: 0.5000
# Epoch 6/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.9033 - accuracy: 0.5646 - val_loss: 0.7259 - val_accuracy: 0.5000
# Epoch 7/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.8941 - accuracy: 0.5771 - val_loss: 0.7027 - val_accuracy: 0.5000
# Epoch 8/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.8432 - accuracy: 0.6052 - val_loss: 0.8778 - val_accuracy: 0.5000
# Epoch 9/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.8142 - accuracy: 0.6396 - val_loss: 0.7071 - val_accuracy: 0.5078
# Epoch 10/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.7784 - accuracy: 0.6609 - val_loss: 0.7595 - val_accuracy: 0.5000
# Epoch 11/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.7296 - accuracy: 0.6740 - val_loss: 0.7137 - val_accuracy: 0.5000
# Epoch 12/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.7597 - accuracy: 0.6562 - val_loss: 0.7116 - val_accuracy: 0.5234
# Epoch 13/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6981 - accuracy: 0.6938 - val_loss: 0.6953 - val_accuracy: 0.5312
# Epoch 14/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.7271 - accuracy: 0.6880 - val_loss: 0.6958 - val_accuracy: 0.5391
# Epoch 15/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6727 - accuracy: 0.7094 - val_loss: 0.6757 - val_accuracy: 0.5391
# Epoch 16/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6889 - accuracy: 0.6901 - val_loss: 0.7166 - val_accuracy: 0.5625
# Epoch 17/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6640 - accuracy: 0.7250 - val_loss: 0.7283 - val_accuracy: 0.5859
# Epoch 18/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6246 - accuracy: 0.7240 - val_loss: 0.6753 - val_accuracy: 0.6016
# Epoch 19/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6439 - accuracy: 0.7068 - val_loss: 0.6742 - val_accuracy: 0.5703
# Epoch 20/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6178 - accuracy: 0.7172 - val_loss: 0.6615 - val_accuracy: 0.5781
# Epoch 21/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.5948 - accuracy: 0.7349 - val_loss: 0.7042 - val_accuracy: 0.5703
# Epoch 22/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.5669 - accuracy: 0.7557 - val_loss: 0.6477 - val_accuracy: 0.6250
# Epoch 23/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.5953 - accuracy: 0.7526 - val_loss: 0.5928 - val_accuracy: 0.6562
# Epoch 24/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.5385 - accuracy: 0.7880 - val_loss: 0.6099 - val_accuracy: 0.6562
# Epoch 25/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.5756 - accuracy: 0.7630 - val_loss: 0.5636 - val_accuracy: 0.6797
# Epoch 26/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.5387 - accuracy: 0.7719 - val_loss: 0.6060 - val_accuracy: 0.6406
# Epoch 27/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.5350 - accuracy: 0.7786 - val_loss: 0.6568 - val_accuracy: 0.6250
# Epoch 28/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4990 - accuracy: 0.7995 - val_loss: 0.5966 - val_accuracy: 0.6250
# Epoch 29/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4843 - accuracy: 0.8026 - val_loss: 0.5837 - val_accuracy: 0.7109
# Epoch 30/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4753 - accuracy: 0.8068 - val_loss: 0.5376 - val_accuracy: 0.7109
# Epoch 31/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4738 - accuracy: 0.8203 - val_loss: 0.6073 - val_accuracy: 0.6641
# Epoch 32/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4522 - accuracy: 0.8276 - val_loss: 0.6015 - val_accuracy: 0.6484
# Epoch 33/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4453 - accuracy: 0.8490 - val_loss: 0.5866 - val_accuracy: 0.6953
# Epoch 34/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4488 - accuracy: 0.8156 - val_loss: 0.5864 - val_accuracy: 0.6797
# Epoch 35/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4156 - accuracy: 0.8365 - val_loss: 0.6843 - val_accuracy: 0.6406
# Epoch 36/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4392 - accuracy: 0.8302 - val_loss: 0.5665 - val_accuracy: 0.6875
# Epoch 37/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.3917 - accuracy: 0.8542 - val_loss: 0.6600 - val_accuracy: 0.6875
# Epoch 38/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.3881 - accuracy: 0.8656 - val_loss: 0.6143 - val_accuracy: 0.6875
# Epoch 39/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.3463 - accuracy: 0.8870 - val_loss: 0.6351 - val_accuracy: 0.7266
# Epoch 40/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3256 - accuracy: 0.8964 - val_loss: 0.5984 - val_accuracy: 0.7344
# Epoch 41/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.3196 - accuracy: 0.8911 - val_loss: 0.5729 - val_accuracy: 0.7578
# Epoch 42/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.3012 - accuracy: 0.9031 - val_loss: 0.6137 - val_accuracy: 0.7500
# Epoch 43/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.2742 - accuracy: 0.9156 - val_loss: 0.5816 - val_accuracy: 0.7422
# Epoch 44/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.2578 - accuracy: 0.9323 - val_loss: 0.6827 - val_accuracy: 0.7344
# Epoch 45/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.2421 - accuracy: 0.9260 - val_loss: 0.5145 - val_accuracy: 0.8281
# Epoch 46/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.2345 - accuracy: 0.9318 - val_loss: 0.5019 - val_accuracy: 0.8438
# Epoch 47/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.2054 - accuracy: 0.9385 - val_loss: 0.4626 - val_accuracy: 0.8281
# Epoch 48/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1974 - accuracy: 0.9375 - val_loss: 0.6062 - val_accuracy: 0.7266
# Epoch 49/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1822 - accuracy: 0.9505 - val_loss: 0.4373 - val_accuracy: 0.8359
# Epoch 50/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1458 - accuracy: 0.9594 - val_loss: 0.4583 - val_accuracy: 0.8359
# Epoch 51/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1376 - accuracy: 0.9667 - val_loss: 0.4323 - val_accuracy: 0.8438
# Epoch 52/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1209 - accuracy: 0.9677 - val_loss: 0.6039 - val_accuracy: 0.7812
# Epoch 53/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1441 - accuracy: 0.9589 - val_loss: 0.6075 - val_accuracy: 0.8125
# Epoch 54/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1025 - accuracy: 0.9724 - val_loss: 0.5430 - val_accuracy: 0.8516
# Epoch 55/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0953 - accuracy: 0.9818 - val_loss: 0.5712 - val_accuracy: 0.8047
# Epoch 56/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0961 - accuracy: 0.9734 - val_loss: 0.4825 - val_accuracy: 0.8281
# Epoch 57/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0850 - accuracy: 0.9776 - val_loss: 0.4748 - val_accuracy: 0.8516
# Epoch 58/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0781 - accuracy: 0.9818 - val_loss: 0.4883 - val_accuracy: 0.8516
# Epoch 59/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0729 - accuracy: 0.9771 - val_loss: 0.5873 - val_accuracy: 0.8203
# Epoch 60/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0993 - accuracy: 0.9750 - val_loss: 0.6493 - val_accuracy: 0.7969
# Epoch 61/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0886 - accuracy: 0.9797 - val_loss: 0.8087 - val_accuracy: 0.7656
# Epoch 62/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0925 - accuracy: 0.9771 - val_loss: 0.5704 - val_accuracy: 0.8125
# Epoch 63/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0812 - accuracy: 0.9786 - val_loss: 0.5660 - val_accuracy: 0.8594
# Epoch 64/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0676 - accuracy: 0.9833 - val_loss: 0.4502 - val_accuracy: 0.8750
# Epoch 65/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0561 - accuracy: 0.9854 - val_loss: 0.4973 - val_accuracy: 0.8359
# Epoch 66/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0439 - accuracy: 0.9906 - val_loss: 0.4991 - val_accuracy: 0.8125
# Epoch 67/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0656 - accuracy: 0.9854 - val_loss: 0.4191 - val_accuracy: 0.8672
# Epoch 68/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0588 - accuracy: 0.9901 - val_loss: 0.5776 - val_accuracy: 0.8359
# Epoch 69/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0542 - accuracy: 0.9854 - val_loss: 0.6209 - val_accuracy: 0.8125
# Epoch 70/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0456 - accuracy: 0.9875 - val_loss: 0.5452 - val_accuracy: 0.8438
# Epoch 71/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0324 - accuracy: 0.9911 - val_loss: 0.5837 - val_accuracy: 0.8203
# Epoch 72/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0364 - accuracy: 0.9937 - val_loss: 0.5858 - val_accuracy: 0.8438
# Epoch 73/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0259 - accuracy: 0.9953 - val_loss: 0.4992 - val_accuracy: 0.8438
# Epoch 74/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0277 - accuracy: 0.9948 - val_loss: 0.4305 - val_accuracy: 0.8438
# Epoch 75/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0433 - accuracy: 0.9896 - val_loss: 0.6666 - val_accuracy: 0.8203
# Epoch 76/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0493 - accuracy: 0.9911 - val_loss: 0.7531 - val_accuracy: 0.8125
# Epoch 77/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0474 - accuracy: 0.9885 - val_loss: 0.6231 - val_accuracy: 0.8359
# Epoch 78/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0354 - accuracy: 0.9932 - val_loss: 0.5673 - val_accuracy: 0.8438
# Epoch 79/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0347 - accuracy: 0.9917 - val_loss: 0.4990 - val_accuracy: 0.8516
# Epoch 80/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0456 - accuracy: 0.9906 - val_loss: 0.4675 - val_accuracy: 0.8672
# Epoch 81/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0502 - accuracy: 0.9880 - val_loss: 0.4662 - val_accuracy: 0.8672
# Epoch 82/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0280 - accuracy: 0.9948 - val_loss: 0.5211 - val_accuracy: 0.8203
# Epoch 83/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0212 - accuracy: 0.9958 - val_loss: 0.4938 - val_accuracy: 0.8281
# Epoch 84/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0395 - accuracy: 0.9948 - val_loss: 0.4424 - val_accuracy: 0.8672
# Epoch 85/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0319 - accuracy: 0.9927 - val_loss: 0.4951 - val_accuracy: 0.8672
# Epoch 86/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0468 - accuracy: 0.9870 - val_loss: 0.4352 - val_accuracy: 0.8672
# Epoch 87/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0416 - accuracy: 0.9896 - val_loss: 0.4794 - val_accuracy: 0.8594
# Epoch 88/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0323 - accuracy: 0.9937 - val_loss: 0.5241 - val_accuracy: 0.8047
# Epoch 89/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0341 - accuracy: 0.9901 - val_loss: 0.6416 - val_accuracy: 0.8203
# Epoch 90/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0323 - accuracy: 0.9917 - val_loss: 0.6263 - val_accuracy: 0.8281
# Epoch 91/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0298 - accuracy: 0.9937 - val_loss: 0.6635 - val_accuracy: 0.7969
# Epoch 92/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0232 - accuracy: 0.9937 - val_loss: 0.6037 - val_accuracy: 0.8203
# Epoch 93/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0259 - accuracy: 0.9943 - val_loss: 0.4364 - val_accuracy: 0.8750
# Epoch 94/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0249 - accuracy: 0.9953 - val_loss: 0.4467 - val_accuracy: 0.8906
# Epoch 95/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0301 - accuracy: 0.9906 - val_loss: 0.5348 - val_accuracy: 0.8516
# Epoch 96/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0225 - accuracy: 0.9948 - val_loss: 0.5286 - val_accuracy: 0.8359
# Epoch 97/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0331 - accuracy: 0.9922 - val_loss: 0.6247 - val_accuracy: 0.8438
# Epoch 98/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0261 - accuracy: 0.9937 - val_loss: 0.5461 - val_accuracy: 0.8438
# Epoch 99/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0308 - accuracy: 0.9932 - val_loss: 0.6102 - val_accuracy: 0.8672
# Epoch 100/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0227 - accuracy: 0.9958 - val_loss: 0.6805 - val_accuracy: 0.8359

# %%
plot_loss(history)
# Out:
# ['loss', 'accuracy', 'val_loss', 'val_accuracy']
# ['loss', 'val_loss']
# ['accuracy', 'val_accuracy']

# %%
x, y = GetSiameseData(new_test, test_y, 10)
res = siamese_network.predict(x)

fig = plt.figure(figsize=[25, 6])
for i in range(10):
    ax = fig.add_subplot(2, 10, i*2 + 1)
    ax.imshow(x[0][i,:,:,0])
    ax.set_title('Pair ' + str(i) +'; Label: ' + str(y[i]))
    ax.axis('off')
    
    ax = fig.add_subplot(2, 10, i*2 + 2)
    ax.imshow(x[1][i,:,:,0])    
    ax.set_title('Predicted: ' + str(res[i]))
    ax.axis('off')

# %%
for i in range(10):
    x[0][i,:] = x[0][0,:]

res = siamese_network.predict(x)

fig = plt.figure(figsize=[25, 6])
for i in range(10):
    ax = fig.add_subplot(2, 10, i*2 + 1)
    ax.imshow(x[0][i,:,:,0])
    ax.set_title('Pair ' + str(i))
    ax.axis('off')
    
    ax = fig.add_subplot(2, 10, i*2 + 2)
    ax.imshow(x[1][i,:,:,0])    
    ax.set_title('Predicted: ' + str(res[i]))
    ax.axis('off')

# %%
embeddings = base_network.predict(test)
tsne_embeddings = TSNE(random_state=4).fit_transform(embeddings)
fig = plt.figure(figsize=[12, 12])
ax = fig.add_subplot(1, 1, 1)
labels = [['No tumor'], ['Meningioma Tumor'], ['Pituitary Tumor'], ['Glioma Tumor']]
ax.scatter(tsne_embeddings[:,0], tsne_embeddings[:,1], c = test_y.flatten(), label=labels);
plt.legend()
plt.show()
# Out:
# c:\Users\61424\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\61424\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
